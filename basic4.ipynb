# %%
import pandas as pd

# %% [markdown]
# ## linear------
# preserve data integrity ,
# smooth trend ,
# avoid data loss

# %% [markdown]
# method -linear ploynomial

# %%
data={
    "Time":[1,2,3,4,5],
    "Value":[10,None,30,None,50]
}
df=pd.DataFrame(data)

# %%
print("before interpolation")
print(df)
# Out:
# before interpolation
#    Time  Value
# 0     1   10.0
# 1     2    NaN
# 2     3   30.0
# 3     4    NaN
# 4     5   50.0

# %%
df['Value']=df['Value'].interpolate(method="linear")
print(df)
# Out:
#    Time  Value
# 0     1   10.0
# 1     2   20.0
# 2     3   30.0
# 3     4   40.0
# 4     5   50.0

# %% [markdown]
# #use where
# #1-time series data
# #2-numeric data with trends
# #3-avoid  dropping rows instead use interploate (fills missing value)

# %% [markdown]
# cannot use to for names id etc
